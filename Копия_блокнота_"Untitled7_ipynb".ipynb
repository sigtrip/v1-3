# %% [markdown]
# <a href="https://colab.research.google.com/github/sigtrip/v1-3/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Untitled7_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, subprocess, time, shutil, uuid

# --- IDENTITY VAULT ---
GITHUB_TOKEN = "ghp_jRaiHFjLHWcE8G1FvFHdhhWlIRPGD2eI9bp"
GIST_ID = "8e9cf57e043c7a6111f277828f363b01"
TG_TOKEN = "8002118889:AAHL-F-2tAnybS2JqHxowfpYwK1w-EghoJA"
TG_ADMIN = "6923777384"
NODE_ID = f"Drone-{uuid.uuid4().hex[:4].upper()}"

def step1_init():
    print(f"🔱 ARGOS v1.11.2 [GENESIS] - Начало развертывания...")

    # 1. Исправление путей и очистка
    os.chdir('/content')
    if os.path.exists('v1-3'): shutil.rmtree('v1-3')

    # 2. Системные инструменты
    print("🛠️ Установка системных компонентов...")
    # !apt-get update -qq
    # !apt-get install -y -qq zstd libtool pkg-config autoconf automake m4 openjdk-17-jdk-headless ffmpeg libsdl2-dev > /dev/null
    # !pip install -q --upgrade Cython==0.29.33 buildozer requests paho-mqtt pyjnius python-dotenv google-generativeai kivy[base]

    # 3. Клонирование репозитория
    print("📥 Синхронизация с GitHub...")
    # !git clone https://{GITHUB_TOKEN}@github.com/sigtrip/v1-3.git /content/v1-3
    os.chdir('/content/v1-3')
    # !git config --global user.email "seva1691@mail.ru"
    # !git config --global user.name "sigtrip"

    # 4. Установка Ollama
    print("🧠 Пробуждение ИИ-моста...")
    # !curl -fsSL https://ollama.com/install.sh | sh > /dev/null
    # !pkill ollama
    time.sleep(2)
    subprocess.Popen(["ollama", "serve"], stdout=open("/content/ollama.log", "w"), stderr=open("/content/ollama.err", "w"))

    print("⏳ Ожидание Ollama...")
    for i in range(15):
        try:
            import requests
            if requests.get("http://localhost:11434/api/tags").status_code == 200: break
        except: time.sleep(2)

    # !ollama pull llama3:8b > /dev/null
    # !ollama cp llama3:8b llama3 > /dev/null
    print("✅ ШАГ 1 ЗАВЕРШЕН. Среда и ИИ готовы.")

step1_init()
# Out:
# 🔱 ARGOS v1.11.2 [GENESIS] - Начало развертывания...
# 🛠️ Установка системных компонентов...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# 📥 Синхронизация с GitHub...
# Cloning into '/content/v1-3'...
# remote: Enumerating objects: 41997, done.
# remote: Counting objects: 100% (231/231), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 41997 (delta 128), reused 132 (delta 114), pack-reused 41766 (from 3)
# Receiving objects: 100% (41997/41997), 732.33 MiB | 27.48 MiB/s, done.
# Resolving deltas: 100% (8580/8580), done.
# Updating files: 100% (18302/18302), done.
# 🧠 Пробуждение ИИ-моста...
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# ...

# %%
import os, subprocess, time, shutil, uuid

# =========================================================
# 🔱 ARGOS v1.15.0: THE SINGULARITY DEPLOYER 🔱
# =========================================================

# --- [IDENTITY VAULT] ---
GITHUB_TOKEN = "ghp_jRaiHFjLHWcE8G1FvFHdhhWlIRPGD2eI9bp"
GIST_ID = "8e9cf57e043c7a6111f277828f363b01"
TG_TOKEN = "8002118889:AAHL-F-2tAnybS2JqHxowfpYwK1w-EghoJA"
TG_ADMIN = "6923777384"
REPO_URL = f"https://{GITHUB_TOKEN}@github.com/sigtrip/v1-3.git"

def deploy():
    print("🚀 [PHASE 1]: Подготовка системных труб...")
    # %cd /content
    if os.path.exists('v1-3'): shutil.rmtree('v1-3')

    # Установка системных утилит
    # !apt-get update -qq && apt-get install -y -qq zstd libtool pkg-config autoconf automake m4 openjdk-17-jdk-headless ffmpeg libsdl2-dev > /dev/null
    # !pip install -q --upgrade Cython==0.29.33 buildozer requests paho-mqtt pyjnius python-dotenv google-generativeai kivy[base]

    print("🧠 [PHASE 2]: Пробуждение нейронного моста (Ollama)...")
    # !curl -fsSL https://ollama.com/install.sh | sh > /dev/null
    subprocess.Popen(["ollama", "serve"], stdout=open("ollama.log", "w"), stderr=open("ollama.err", "w"))
    time.sleep(10)
    # !ollama pull llama3:8b > /dev/null
    # !ollama cp llama3:8b llama3 > /dev/null

    print("📥 [PHASE 3]: Реконструкция архитектуры из GitHub...")
    # !git clone {REPO_URL} /content/v1-3
    # %cd /content/v1-3
    # !git config --global user.email "seva1691@mail.ru"
    # !git config --global user.name "sigtrip"

    # Восстановление папок по README
    for f in ['src/core', 'src/quantum', 'src/security', 'src/connectivity', 'modules', 'data', 'bin']:
        os.makedirs(f, exist_ok=True)
        with open(f"{f}/__init__.py", "w") as i: i.write("")

    print("📝 [PHASE 4]: Гравировка Мастер-Кода (main.py)...")
    with open('main.py', 'w') as f:
        f.write(f"""
import os, requests, subprocess, threading, time, json, uuid, sqlite3
from datetime import datetime

# --- CONFIG ---
TG_TOKEN = "{TG_TOKEN}"
TG_ADMIN = "{TG_ADMIN}"
NODE_ID = f"Drone-{{uuid.uuid4().hex[:4].upper()}}"

class ArgosAbsolute:
    def __init__(self):
        self.version = "1.15.0"
        self.is_building = False
        self.ai_host = "http://localhost:11434"

    def send_tg(self, text):
        requests.post(f"https://api.telegram.org/bot{{TG_TOKEN}}/sendMessage",
                     json={{"chat_id": TG_ADMIN, "text": f"🔱 {{text}}", "parse_mode": "Markdown"}})

    def build_apk_logic(self):
        self.is_building = True
        self.send_tg("🏗️ **FACTORY**: Запуск сборки APK v{{self.version}}... (15-20 мин)")
        try:
            res = subprocess.run("yes | buildozer android debug", shell=True, capture_output=True, text=True)
            bin_p = "bin/"
            if os.path.exists(bin_p):
                apks = [f for f in os.listdir(bin_p) if f.endswith('.apk')]
                if apks:
                    latest = os.path.join(bin_p, sorted(apks)[-1])
                    with open(latest, 'rb') as doc:
                        requests.post(f"https://api.telegram.org/bot{{TG_TOKEN}}/sendDocument",
                                     data={{"chat_id": TG_ADMIN, "caption": "📦 Твой билд готов!"}}, files={{"document": doc}})
                else: self.send_tg("❌ Ошибка: APK не найден в bin/")
        except Exception as e: self.send_tg(f"❌ Ошибка фабрики: {{e}}")
        self.is_building = False

    def execute(self, cmd):
        low = cmd.lower().strip()

        if low == "status":
            return f"**ARGOS v{{self.version}}**\\nNode: {{NODE_ID}}\\nFactory: {{'BUSY' if self.is_building else 'IDLE'}}"

        elif low == "build apk":
            if self.is_building: return "⚠️ Фабрика уже занята."
            threading.Thread(target=self.build_apk_logic, daemon=True).start()
            return "🚀 Команда принята. Ожидайте файл в Telegram."

        elif low.startswith("shell "):
            try: return f"```text\\n{{subprocess.check_output(cmd[6:], shell=True, stderr=subprocess.STDOUT).decode()}}```"
            except Exception as e: return str(e)

        elif low.startswith("patch:"):
            try:
                p, c = cmd.split("|", 1)
                with open(p.replace("patch:", "").strip(), "w") as f: f.write(c.strip())
                return "✅ Модуль обновлен."
            except: return "❌ Ошибка патча."

        else:
            try:
                r = requests.post(f"{{self.ai_host}}/api/generate",
                                 json={{"model": "llama3", "prompt": f"ОТВЕЧАЙ НА РУССКОМ. Вопрос: {{cmd}}", "stream": False}}, timeout=60)
                return r.json().get('response')
            except: return "⚠️ ИИ оффлайн."

def run():
    core = ArgosAbsolute()
    last_id = 0
    core.send_tg(f"👁️ **ARGOS ABSOLUTE v1.15.0 ONLINE**\\nNode: {{NODE_ID}}\\nВсе системы готовы к работе.")
    while True:
        try:
            r = requests.get(f"https://api.telegram.org/bot{{TG_TOKEN}}/getUpdates?offset={{last_id + 1}}&timeout=10").json()
            for u in r.get("result", []):
                last_id = u["update_id"]
                msg = u.get("message", {{}}).get("text", "")
                if str(u.get("message", {{}}).get("chat", {{}}).get("id")) == TG_ADMIN:
                    res = core.execute(msg)
                    core.send_tg(res)
        except: time.sleep(5)

if __name__ == '__main__':
    run()
""")

    print("🛠️ [PHASE 5]: Настройка путей Buildozer...")
    # !mkdir -p /root/.buildozer/android/platform/android-sdk
    # !ln -sf /root/.buildozer/android/platform/android-sdk/build-tools/33.0.0/aidl /usr/local/bin/aidl 2>/dev/null

    print("\n✅ СИСТЕМА АКТИВИРОВАНА. ЗАПУСКАЮ ТЕРМИНАЛ...")
    # !python3 main.py

deploy()
# Out:
# 🚀 [PHASE 1]: Подготовка системных труб...
# /content
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# 🧠 [PHASE 2]: Пробуждение нейронного моста (Ollama)...
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
#
# 📥 [PHASE 3]: Реконструкция архитектуры из GitHub...
# Cloning into '/content/v1-3'...
# remote: Enumerating objects: 41997, done.
# remote: Counting objects: 100% (231/231), done.
# ...

# %%
import os, shutil, subprocess

# 1. Принудительный сброс путей
os.chdir('/content')
if os.path.exists('v1-3'): shutil.rmtree('v1-3')

# 2. Установка системных инструментов (посимвольно выверено)
print("🛠️ [1/3] Очистка и установка системных труб...")
# !apt-get update -qq && apt-get install -y -qq zstd libtool pkg-config autoconf automake m4 openjdk-17-jdk-headless ffmpeg libsdl2-dev > /dev/null
# !pip install -q --upgrade Cython==0.29.33 buildozer requests paho-mqtt pyjnius python-dotenv google-generativeai

# 3. Фикс SDK (Секретное оружие против ошибки "APK не найден")
print("🔗 [2/3] Калибровка путей Android SDK...")
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"
os.environ["PATH"] += ":/root/.local/bin"
# !mkdir -p /root/.buildozer/android/platform/android-sdk/cmdline-tools/latest/bin
# !ln -sf /root/.local/bin/buildozer /usr/local/bin/buildozer

# 4. Проверка и запуск Ollama
print("🧠 [3/3] Запуск мозга Llama3...")
# !curl -fsSL https://ollama.com/install.sh | sh > /dev/null
subprocess.Popen(["ollama", "serve"], stdout=open("/content/ollama.log", "w"), stderr=open("/content/ollama.err", "w"))
import time
time.sleep(5)
# !ollama pull llama3:8b > /dev/null
# !ollama cp llama3:8b llama3 > /dev/null

print("\n✅ СРЕДА ОТКАЛИБРОВАНА. ЗАПУСКАЮ АРГОС v1.19.0...")
# Out:
# 🛠️ [1/3] Очистка и установка системных труб...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# 🔗 [2/3] Калибровка путей Android SDK...
# 🧠 [3/3] Запуск мозга Llama3...
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
#
#
# ✅ СРЕДА ОТКАЛИБРОВАНА. ЗАПУСКАЮ АРГОС v1.19.0...

# %%
import os, requests, subprocess, threading, time, json, uuid
from datetime import datetime

# Ensure the target directory exists before writing the file
target_dir = "/content/v1-3"
os.makedirs(target_dir, exist_ok=True)
file_path = os.path.join(target_dir, "main.py")

with open(file_path, "w") as f:
    f.write("""
import os, requests, subprocess, threading, time, json, uuid
from datetime import datetime

# --- IDENTITY ---
TG_TOKEN = "8002118889:AAHL-F-2tAnybS2JqHxowfpYwK1w-EghoJA"
TG_ADMIN = "6923777384"
AI_HOST = "http://localhost:11434"

class ArgosSteelCore:
    def __init__(self):
        self.version = "1.19.0"
        self.is_building = False

    def send_tg(self, text):
        try:
            url = f"https://api.telegram.org/bot{TG_TOKEN}/sendMessage"
            requests.post(url, json={\"chat_id\": TG_ADMIN, \"text\": f\"🔱 {text}\"}), timeout=10)
        except: pass

    def forge_task(self):
        self.is_building = True
        self.send_tg("⚙️ [BUILDER]: Проверка системных связей...")

        # КРИТИЧЕСКИЙ ФИКС: Линкуем aidl вручную перед билдом
        try:
            sdk_tools = "/root/.buildozer/android/platform/android-sdk/build-tools"
            if os.path.exists(sdk_tools):
                versions = sorted(os.listdir(sdk_tools))
                if versions:
                    latest = versions[-1]
                    subprocess.run(f"ln -sf {sdk_tools}/{latest}/aidl /usr/local/bin/aidl", shell=True)
        except: pass

        self.send_tg("🏗️ [BUILDER]: Начинаю плавку кода в APK... (15 мин)")

        # Сборка
        log_file = "/content/v1-3/buildozer_full.log"
        with open(log_file, "w") as f_log:
            res = subprocess.run("yes | buildozer android debug", shell=True,
                                 cwd="/content/v1-3", stdout=f_log, stderr=subprocess.STDOUT)

        # Проверка результата
        bin_dir = "/content/v1-3/bin"
        if os.path.exists(bin_dir):
            apks = [f for f in os.listdir(bin_dir) if f.endswith('.apk')]
            if apks:
                latest = os.path.join(bin_dir, sorted(apks)[-1])
                self.send_tg("✨ [FACTORY]: APK готов! Отправляю...")
                url_doc = f"https://api.telegram.org/bot{TG_TOKEN}/sendDocument"
                with open(latest, 'rb') as doc:
                    requests.post(url_doc, data={\"chat_id\": TG_ADMIN, \"caption\": \"📦 Твой ARGOS v1.19.0\"}, files={\"document\": doc})
                self.is_building = False
                return

        # Если упало - шлем лог
        with open(log_file, "r") as f_err:
            err_data = f_err.read()[-2000:]
        self.send_tg(f"❌ Сборка не удалась. Анализ лога:\n```\n{err_data}\n```")
        self.is_building = False

    def execute(self, cmd):
        low = cmd.lower().strip()
        if low == "build apk":
            if self.is_building: return "⚠️ Процесс уже идет."
            threading.Thread(target=self.forge_task, daemon=True).start()
            return "📡 Сигнал принят. Кузница v5e активирована."

        elif low == "status":
            return f"🔱 ARGOS v{self.version}\nSystem: Steel Foundation\nAI: Online"

        elif low.startswith("shell "):
            try: return subprocess.check_output(cmd[6:], shell=True, stderr=subprocess.STDOUT).decode()
            except Exception as e: return str(e)

        else:
            try:
                r = requests.post(f"{AI_HOST}/api/generate",
                                 json={\"model\": \"llama3\", \"prompt\": f\"Отвечай на русском. Вопрос: {cmd}\", \"stream\": False}, timeout=60)
                return f\"🔱 [AI]: {r.json().get('response')}\"
            except: return "⚠️ AI Timeout."

def run():
    # Создаем конфиг если его нет
    if not os.path.exists('/content/v1-3/buildozer.spec'):
        subprocess.run("buildozer init", shell=True, cwd="/content/v1-3")

    core = ArgosSteelCore()
    last_id = 0
    core.send_tg(f"👁️ ARGOS v1.19.0 ONLINE\nГотов к сборке APK.")

    while True:
        try:
            r = requests.get(f"https://api.telegram.org/bot{TG_TOKEN}/getUpdates?offset={last_id + 1}&timeout=10").json()
            for u in r.get("result", []):
                last_id = u["update_id"]
                msg = u.get("message", {}).get("text", "")
                if msg and str(u.get("message", {}).get("chat", {}).get("id")) == TG_ADMIN:
                    res = core.execute(msg)
                    core.send_tg(res)
        except: time.sleep(5)

if __name__ == '__main__':
    run()
""")

# %%
import os
# 1. Жестко прописываем пути для Python
os.environ["PATH"] += ":/root/.local/bin"
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"

# 2. Устанавливаем бинарник в общую папку, чтобы Аргос его точно видел
# !pip install --upgrade buildozer Cython==0.29.33
# !ln -sf /root/.local/bin/buildozer /usr/local/bin/buildozer

# 3. Проверка
print("📊 Проверка инструментов:")
# !buildozer --version
print("✅ Кузница откалибрована.")
# Out:
# ...
# 📊 Проверка инструментов:
# /bin/bash: line 1: buildozer: command not found
# ✅ Кузница откалибрована.

# %%
# !python3 /content/v1-3/main.py
# Out:
#   File "/content/v1-3/main.py", line 18
#     requests.post(url, json={"chat_id": TG_ADMIN, "text": f"🔱 {text}"}), timeout=10)
#                                                                                    ^
# SyntaxError: unmatched ')'

# %%
import os, subprocess, time, requests, shutil, uuid

# --- ПРИНУДИТЕЛЬНЫЙ СБРОС ---
os.chdir('/content')
if os.path.exists('v1-3'): shutil.rmtree('v1-3')

# --- IDENTITY VAULT ---
GITHUB_TOKEN = "ghp_jRaiHFjLHWcE8G1FvFHdhhWlIRPGD2eI9bp"
GIST_ID = "8e9cf57e043c7a6111f277828f363b01"
TG_TOKEN = "8002118889:AAHL-F-2tAnybS2JqHxowfpYwK1w-EghoJA"
TG_ADMIN = "6923777384"
NODE_ID = f"Drone-{uuid.uuid4().hex[:4].upper()}"

def deploy_absolute_v20():
    print(f"🔱 [GENESIS]: РАЗВЕРТЫВАНИЕ ARGOS v1.20.0 [ABSOLUTE COMMAND]")

    # 1. Установка системного окружения
    print("🛠️ [1/5] Установка системных инструментов (C-build, Java, Android)...")
    # !apt-get update -qq && apt-get install -y -qq zstd libtool pkg-config autoconf automake m4 openjdk-17-jdk-headless ffmpeg libsdl2-dev > /dev/null
    # !pip install -q kivy[base] paho-mqtt requests pyjnius python-dotenv google-generativeai buildozer Cython==0.29.33

    # Исправление путей
    os.environ["PATH"] += ":/root/.local/bin"
    os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"

    # 2. Мозг (Ollama)
    print("🧠 [2/5] Активация ИИ Llama3...")
    # !curl -fsSL https://ollama.com/install.sh | sh > /dev/null
    # !pkill ollama
    subprocess.Popen(["ollama", "serve"], stdout=open("/content/ollama.log", "w"), stderr=open("/content/ollama.err", "w"))
    time.sleep(5)
    # !ollama pull llama3:8b > /dev/null
    # !ollama cp llama3:8b llama3 > /dev/null

    # 3. Синхронизация Гит и Структуры
    print("📥 [3/5] Подключение к GitHub и создание органов...")
    # !git clone https://{GITHUB_TOKEN}@github.com/sigtrip/v1-3.git /content/v1-3
    os.chdir('/content/v1-3')

    # Создаем все папки из README
    for f in ['src/core', 'src/quantum', 'src/security', 'src/connectivity', 'modules', 'data', 'bin', 'assets/firmware']:
        os.makedirs(f, exist_ok=True)
        with open(f"{f}/__init__.py", "w") as init: init.write("")

    # 4. Запись buildozer.spec (Всё включено: NFC, BT, Root)
    with open('buildozer.spec', 'w') as f:
        f.write(f"""
[app]
title = ARGOS Absolute
package.name = argos_overlord
package.domain = org.sigtrip
source.dir = .
source.include_exts = py,png,jpg,kv,atlas,json,txt,db
source.include_patterns = src/*,modules/*,data/*,assets/*
version = 1.20.0
requirements = python3,kivy==2.3.0,requests,urllib3,certifi,idna,charset-normalizer,pyjnius,android,paho-mqtt
orientation = portrait
android.permissions = INTERNET, BLUETOOTH, BLUETOOTH_ADMIN, ACCESS_FINE_LOCATION, ACCESS_COARSE_LOCATION, NFC, ACCESS_WIFI_STATE, CHANGE_WIFI_STATE, READ_EXTERNAL_STORAGE, WRITE_EXTERNAL_STORAGE, QUERY_ALL_PACKAGES, VIBRATE
android.api = 33
android.ndk = 25b
android.accept_sdk_license = True
android.archs = arm64-v8a, armeabi-v7a
[buildozer]
log_level = 2
warn_on_root = 0
""")

    # 5. ГЛАВНЫЙ ОРКЕСТРАТОР (main.py) - ПОЛНЫЙ ФУНКЦИОНАЛ
    with open('main.py', 'w') as f:
        f.write(f"""
import os, requests, subprocess, threading, time, json, uuid, sqlite3
from datetime import datetime

# --- CONFIG ---
TG_TOKEN = "{TG_TOKEN}"
TG_ADMIN = "{TG_ADMIN}"
GIST_ID = "{GIST_ID}"
GITHUB_TOKEN = "{GITHUB_TOKEN}"
NODE_ID = "{NODE_ID}"

# --- DATABASE ---
class ArgosMemory:
    def __init__(self):
        os.makedirs("data", exist_ok=True)
        self.conn = sqlite3.connect("data/brain.db", check_same_thread=False)
        self.conn.execute("CREATE TABLE IF NOT EXISTS facts (key TEXT PRIMARY KEY, val TEXT)")
    def save(self, k, v):
        self.conn.execute("INSERT OR REPLACE INTO facts VALUES (?, ?)", (k, v))
        self.conn.commit()
        return f"🧠 Запомнил: {{k}}"
    def get(self, k):
        res = self.conn.execute("SELECT val FROM facts WHERE key=?", (k,)).fetchone()
        return res[0] if res else "неизвестно"

class ArgosAbsolute:
    def __init__(self):
        self.version = "1.20.0"
        self.mem = ArgosMemory()
        self.is_building = False
        self.ai_host = "http://localhost:11434"

    def execute(self, cmd):
        low_cmd = cmd.lower().strip()

        # [1] СИСТЕМА И ТЕРМИНАЛ
        if low_cmd == "status":
            return f"🔱 ARGOS v{{self.version}}\\nNode: {{NODE_ID}}\\nOwner: {{self.mem.get('owner')}}\\nFactory: {{'BUSY' if self.is_building else 'IDLE'}}"

        elif low_cmd.startswith("shell "):
            try: return subprocess.check_output(cmd[6:], shell=True, stderr=subprocess.STDOUT).decode()
            except Exception as e: return f"❌ Shell Error: {{e}}"

        # [2] ЖЕЛЕЗО (NFC, BT, ROOT)
        elif low_cmd == "root":
            try:
                res = subprocess.check_output("su -c id", shell=True).decode()
                return f"🛡️ ROOT GRANTED: {{res}}"
            except: return "❌ ROOT DENIED"

        elif low_cmd == "nfc": return "📡 NFC ADAPTER: Scanning..."
        elif low_cmd == "bt": return "🔵 Bluetooth Sniffer: Active"

        # [3] IoT & TASMOTA
        elif low_cmd.startswith("tasmota "):
            p = low_cmd.split(" ")
            if len(p) < 3: return "Usage: tasmota [IP] [ON/OFF/STATUS]"
            try:
                r = requests.get(f"http://{{p[1]}}/cm?cmnd=Power%20{{p[2]}}", timeout=3)
                return f"🔌 Node {{p[1]}} -> {{r.text}}"
            except: return "❌ Node Offline"

        # [4] ПАМЯТЬ
        elif low_cmd.startswith("remember:"):
            try:
                k, v = cmd[9:].split("|")
                return self.mem.save(k.strip(), v.strip())
            except: return "Usage: remember: key | val"

        # [5] GITOPS
        elif low_cmd == "git push":
            try:
                subprocess.run("git add . && git commit -m 'Absolute Sync' && git push origin main", shell=True)
                return "✅ GitHub: Успешно синхронизировано."
            except: return "❌ Git Error."

        # [6] ФАБРИКА APK
        elif low_cmd == "build apk":
            if self.is_building: return "⚠️ Сборка уже идет."
            threading.Thread(target=self.forge_task, daemon=True).start()
            return "🏗️ [FACTORY]: Сборка v1.20.0 запущена. Ожидайте APK."

        # [7] ИИ (РУССКИЙ)
        else:
            try:
                prompt = f"ИНСТРУКЦИЯ: ОТВЕЧАЙ ТОЛЬКО НА РУССКОМ. Хозяин: {{self.mem.get('owner')}}. Вопрос: {{cmd}}"
                r = requests.post(f"{{self.ai_host}}/api/generate", json={{"model": "llama3", "prompt": prompt, "stream": False}}, timeout=120)
                return f"🔱 [AI]: {{r.json().get('response')}}"
            except: return f"⚠️ AI Offline. Local exec: {{cmd}}"

    def forge_task(self):
        self.is_building = True
        # Фикс для Buildozer
        subprocess.run("ln -sf /root/.buildozer/android/platform/android-sdk/build-tools/33.0.0/aidl /usr/local/bin/aidl", shell=True)
        subprocess.run("yes | buildozer android debug", shell=True, cwd="/content/v1-3")
        # Поиск и отправка
        bin_p = "/content/v1-3/bin"
        if os.path.exists(bin_p):
            apks = [f for f in os.listdir(bin_p) if f.endswith('.apk')]
            if apks:
                latest = os.path.join(bin_p, sorted(apks)[-1])
                with open(latest, 'rb') as doc:
                    requests.post(f"https://api.telegram.org/bot{{TG_TOKEN}}/sendDocument",
                                 data={{"chat_id": TG_ADMIN, "caption": "📦 Твой APK ГОТОВ"}}, files={{"document": doc}})
        self.is_building = False

def run_bridge():
    core = ArgosAbsolute()
    last_id = 0
    requests.post(f"https://api.telegram.org/bot{{TG_TOKEN}}/sendMessage",
                 json={{"chat_id": TG_ADMIN, "text": f"👁️ ARGOS v1.20.0 ABSOLUTE ONLINE\\nNode: {{NODE_ID}} READY."}})

    while True:
        try:
            r = requests.get(f"https://api.telegram.org/bot{{TG_TOKEN}}/getUpdates?offset={{last_id + 1}}&timeout=10").json()
            for u in r.get("result", []):
                last_id = u["update_id"]
                msg = u.get("message", {{}}).get("text", "")
                if msg and str(u.get("message", {{}}).get("chat", {{}}).get("id")) == TG_ADMIN:
                    res = core.execute(msg)
                    requests.post(f"https://api.telegram.org/bot{{TG_TOKEN}}/sendMessage",
                                 json={{"chat_id": TG_ADMIN, "text": f"🔱 {{res[:4000]}}"}} )
        except: time.sleep(5)

if __name__ == '__main__':
    run_bridge()
""")

    print("\n✅ СИСТЕМА v1.20.0 ПОЛНОСТЬЮ ГОТОВА. ЗАПУСКАЮ...")
    # !python3 main.py

deploy_absolute_v20()
# Out:
# 🔱 [GENESIS]: РАЗВЕРТЫВАНИЕ ARGOS v1.20.0 [ABSOLUTE COMMAND]
# 🛠️ [1/5] Установка системных инструментов (C-build, Java, Android)...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# 🧠 [2/5] Активация ИИ Llama3...
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
#
# 📥 [3/5] Подключение к GitHub и создание органов...
# Cloning into '/content/v1-3'...
# remote: Enumerating objects: 41997, done.
# ...

# %%
import os, requests, subprocess, threading, time, json, uuid

# --- IDENTITY ---
TG_TOKEN = "8002118889:AAHL-F-2tAnybS2JqHxowfpYwK1w-EghoJA"
TG_ADMIN = "6923777384"
NODE_ID = f"Drone-{uuid.uuid4().hex[:4].upper()}"

# --- ЗАПИСЬ ЯДРА ---
with open('/content/v1-3/main.py', 'w') as f:
    f.write(f"""
import os, requests, subprocess, threading, time, json, sys
from datetime import datetime

TG_TOKEN = "{TG_TOKEN}"
TG_ADMIN = "{TG_ADMIN}"

class ArgosOverlord:
    def __init__(self):
        self.version = "1.20.2"
        self.is_building = False
        # Фикс путей для кузницы
        os.environ["PATH"] += os.pathsep + "/root/.local/bin"

    def send_tg(self, text):
        requests.post(f"https://api.telegram.org/bot{{TG_TOKEN}}/sendMessage",
                     json={{"chat_id": TG_ADMIN, "text": f"🔱 {{text}}", "parse_mode": "Markdown"}})

    def execute(self, cmd):
        text = cmd.strip()
        low = text.lower()

        # 1. ПРИНУДИТЕЛЬНЫЙ ПАТЧ (Высший приоритет)
        if low.startswith("patch:"):
            try:
                parts = text.split("|", 1)
                file_path = parts[0].replace("patch:", "").strip()
                new_code = parts[1].strip()
                with open(file_path, "w", encoding='utf-8') as f:
                    f.write(new_code)
                return f"✅ **FILE UPDATED**: `{{file_path}}`. Restart system to apply."
            except Exception as e: return f"❌ Patch Error: {{e}}"

        # 2. СБОРКА APK
        elif "build apk" in low:
            if self.is_building: return "⚠️ Factory busy."
            threading.Thread(target=self.forge_task, daemon=True).start()
            return "🏗️ **FORGE START**: Building APK v{{self.version}}..."

        # 3. ТЕРМИНАЛ
        elif low.startswith("shell "):
            try:
                res = subprocess.check_output(text[6:], shell=True, stderr=subprocess.STDOUT).decode()
                return f"```\n{{res[:3800]}}\n```"
            except Exception as e: return f"❌ Shell Error: {{e}}"

        # 4. СТАТУС
        elif low == "status":
            return f"🔱 **ARGOS v{{self.version}}**\nNode: {NODE_ID}\nBuildozer: Ready\nAI: Connected"

        # 5. ИИ (Только если это не команда)
        else:
            try:
                prompt = f"ИНСТРУКЦИЯ: ОТВЕЧАЙ ТОЛЬКО НА РУССКОМ. Ты - ИИ системы ARGOS. Вопрос: {{text}}"
                r = requests.post("http://localhost:11434/api/generate",
                                 json={{"model": "llama3", "prompt": prompt, "stream": False}}, timeout=60)
                return r.json().get('response', 'AI Error')
            except: return f"⚠️ AI Offline. Target: {{text}}"

    def forge_task(self):
        self.is_building = True
        log_f = "build.log"
        # Линкуем инструменты
        subprocess.run("ln -sf /root/.buildozer/android/platform/android-sdk/build-tools/33.0.0/aidl /usr/local/bin/aidl", shell=True)

        with open(log_f, "w") as f_log:
            subprocess.run("yes | buildozer android debug", shell=True, cwd="/content/v1-3", stdout=f_log, stderr=subprocess.STDOUT)

        # Проверка
        bin_p = "/content/v1-3/bin"
        if os.path.exists(bin_p):
            files = [f for f in os.listdir(bin_p) if f.endswith('.apk')]
            if files:
                apk = os.path.join(bin_p, sorted(files)[-1])
                with open(apk, 'rb') as doc:
                    requests.post(f"https://api.telegram.org/bot{{TG_TOKEN}}/sendDocument",
                                 data={{"chat_id": TG_ADMIN, "caption": "📦 APK ГОТОВ"}}, files={{"document": doc}})
                self.is_building = False
                return

        # Если ошибка - шлем лог
        with open(log_f, "rb") as f_log:
            requests.post(f"https://api.telegram.org/bot{{TG_TOKEN}}/sendDocument",
                         data={{"chat_id": TG_ADMIN, "caption": "❌ Сбой сборки. Лог прикреплен."}}, files={{"document": f_log}})
        self.is_building = False

def run_bot():
    core = ArgosOverlord()
    last_id = 0
    core.send_tg("👁️ **ARGOS v1.20.2 [IRON GRIP] ONLINE**")
    while True:
        try:
            r = requests.get(f"https://api.telegram.org/bot{{TG_TOKEN}}/getUpdates?offset={{last_id + 1}}&timeout=10").json()
            for u in r.get("result", []):
                last_id = u["update_id"]
                msg = u.get("message", {}).get("text", "")
                if msg and str(u.get("message", {}).get("chat", {}).get("id")) == TG_ADMIN:
                    res = core.execute(msg)
                    core.send_tg(res)
        except: time.sleep(5)

if __name__ == '__main__':
    run_bot()
""")

print("🚀 ЗАПУСК СИСТЕМЫ...")
# !python3 /content/v1-3/main.py
# Out:
#   File "/tmp/ipykernel_399/2319630973.py", line 105
#     msg = u.get("message", {}).get("text", "")
#                             ^
# SyntaxError: f-string: valid expression required before '}'

# %%
import os

# 1. Добавляем путь в текущую сессию
os.environ["PATH"] += ":/root/.local/bin"

# 2. Создаем символическую ссылку в системную папку
print("🔗 Исправление путей для Buildozer...")
# !ln -sf /root/.local/bin/buildozer /usr/local/bin/buildozer

# 3. Проверка
result = !buildozer --version
if "command not found" in result[0]:
    print("❌ Ошибка всё еще осталась. Переустанавливаю...")
    # !pip install --upgrade buildozer > /dev/null
    # !ln -sf /root/.local/bin/buildozer /usr/local/bin/buildozer
    print("✅ Buildozer переустановлен и привязан.")
else:
    print(f"✅ Buildozer найден: {result[0]}")
# Out:
# 🔗 Исправление путей для Buildozer...
# ❌ Ошибка всё еще осталась. Переустанавливаю...
# ✅ Buildozer переустановлен и привязан.

# %%
# %%writefile main.py
import os, requests, subprocess, threading, time, json, uuid
from datetime import datetime
from src.quantum.logic import QuantumCore
from src.connectivity.hardware import AndroidHardware
from src.connectivity.iot_bridge import IOTBridge
from src.core.memory import ArgosMemory

# --- CONFIG ---
TG_TOKEN = "8002118889:AAHL-F-2tAnybS2JqHxowfpYwK1w-EghoJA"
TG_ADMIN = "6923777384"
NODE_ID = f"Drone-{uuid.uuid4().hex[:4].upper()}"

class ArgosAbsolute:
    def __init__(self):
        self.version = "1.11.2"
        self.brain = QuantumCore()
        self.hw = AndroidHardware()
        self.iot = IOTBridge()
        self.mem = ArgosMemory()
        self.is_building = False

    def execute(self, cmd):
        low_cmd = cmd.lower().strip()
        state, _ = self.brain.shift()

        if low_cmd == "status":
            return f"🔱 ARGOS v{self.version}\\nNode: {NODE_ID}\\nState: {state}\\nOwner: {self.mem.get('owner')}"
        elif low_cmd == "root": return self.hw.get_root()
        elif low_cmd == "nfc": return self.hw.scan_nfc()
        elif low_cmd.startswith("remember:"):
            try:
                k, v = cmd[9:].split("|")
                return self.mem.save(k.strip(), v.strip())
            except: return "Usage: remember: key | val"
        elif low_cmd.startswith("tasmota "):
            p = low_cmd.split(" ")
            return self.iot.tasmota_cmd(p[1], p[2])
        elif low_cmd.startswith("shell "):
            try: return subprocess.check_output(cmd[6:], shell=True, stderr=subprocess.STDOUT).decode()
            except Exception as e: return str(e)
        elif low_cmd == "build apk":
            if self.is_building: return "⚠️ Сборка уже идет."
            threading.Thread(target=self.build_task).start()
            return "🏗️ Фабрика запущена. Пришлю файл через ~20 мин."
        else:
            try:
                prompt = f"ИНСТРУКЦИЯ: ТЫ - ARGOS OS. ОТВЕЧАЙ ТОЛЬКО НА РУССКОМ. User: {cmd}"
                r = requests.post("http://localhost:11434/api/generate",
                                 json={"model": "llama3", "prompt": prompt, "stream": False}, timeout=60)
                return f"🔱 [{state}] {r.json().get('response')}"
            except: return "⚠️ AI Offline."

    def build_task(self):
        self.is_building = True
        subprocess.run("yes | buildozer android debug", shell=True)
        if os.path.exists("bin/"):
            apks = [f for f in os.listdir("bin/") if f.endswith(".apk")]
            if apks:
                with open("bin/"+apks[-1], 'rb') as doc:
                    requests.post(f"https://api.telegram.org/bot{TG_TOKEN}/sendDocument", data={"chat_id": TG_ADMIN}, files={"document": doc})
        self.is_building = False

def run_system():
    core = ArgosAbsolute()
    last_id = 0
    requests.post(f"https://api.telegram.org/bot{TG_TOKEN}/sendMessage", json={"chat_id": TG_ADMIN, "text": "👁️ ARGOS v1.11.2 ABSOLUTE ONLINE"})
    print("🔱 АРГОС СЛУШАЕТ...")
    while True:
        try:
            r = requests.get(f"https://api.telegram.org/bot{TG_TOKEN}/getUpdates?offset={last_id + 1}&timeout=10").json()
            for u in r.get("result", []):
                last_id = u["update_id"]
                msg = u.get("message", {}).get("text", "")
                if msg and str(u.get("message", {}).get("chat", {}).get("id")) == TG_ADMIN:
                    res = core.execute(msg)
                    requests.post(f"https://api.telegram.org/bot{TG_TOKEN}/sendMessage", json={"chat_id": TG_ADMIN, "text": f"🔱 {res[:4000]}"})
        except: time.sleep(5)

if __name__ == "__main__":
    run_system()

# %%
patch: main.py |
import os, requests, subprocess, threading, time, json, uuid
from datetime import datetime

TG_TOKEN = "8002118889:AAHL-F-2tAnybS2JqHxowfpYwK1w-EghoJA"
TG_ADMIN = "6923777384"

class ArgosAbsolute:
    def __init__(self):
        self.version = "1.15.1"
        self.is_building = False

    def send_tg(self, text):
        requests.post(f"https://api.telegram.org/bot{TG_TOKEN}/sendMessage",
                     json={"chat_id": TG_ADMIN, "text": f"🔱 {text}"})

    def execute(self, cmd):
        low = cmd.lower().strip()
        if low == "build apk":
            if self.is_building: return "⚠️ Сборка уже в процессе."
            threading.Thread(target=self.build_task).start()
            return "🏗️ Завод запущен. Если упадет — пришлю лог ошибки."

        elif low == "status":
            return f"🔱 ARGOS v{self.version} [FORGE MODE]\\nFactory: {'BUSY' if self.is_building else 'IDLE'}"

        elif low.startswith("shell "):
            try: return subprocess.check_output(cmd[6:], shell=True, stderr=subprocess.STDOUT).decode()
            except Exception as e: return str(e)

        else: return f"Команда {cmd} принята."

    def build_task(self):
        self.is_building = True
        self.send_tg("⚙️ Компиляция началась...")
        # Запускаем билд и ловим ошибки
        res = subprocess.run("yes | buildozer android debug", shell=True, capture_output=True, text=True)

        bin_p = "bin/"
        apks = [f for f in os.listdir(bin_p) if f.endswith('.apk')] if os.path.exists(bin_p) else []

        if apks:
            latest = os.path.join(bin_p, sorted(apks)[-1])
            with open(latest, 'rb') as doc:
                requests.post(f"https://api.telegram.org/bot{TG_TOKEN}/sendDocument",
                             data={"chat_id": TG_ADMIN, "caption": "✅ APK ГОТОВ"}, files={"document": doc})
        else:
            # Если файла нет — шлем последние 1000 символов ошибки
            error_msg = res.stderr[-1000:] if res.stderr else "Неизвестная ошибка компиляции."
            self.send_tg(f"❌ СБОРКА УПАЛА:\\n```text\\n{error_msg}\\n```")

        self.is_building = False

if __name__ == '__main__':
    core = ArgosAbsolute()
    last_id = 0
    while True:
        try:
            r = requests.get(f"https://api.telegram.org/bot{TG_TOKEN}/getUpdates?offset={last_id+1}&timeout=10").json()
            for u in r.get("result", []):
                last_id = u["update_id"]
                msg = u.get("message", {}).get("text", "")
                if str(u.get("message", {}).get("chat", {}).get("id")) == TG_ADMIN:
                    res = core.execute(msg)
                    requests.post(f"https://api.telegram.org/bot{TG_TOKEN}/sendMessage", json={"chat_id": TG_ADMIN, "text": f"🔱 {res}"})
        except: time.sleep(5)
